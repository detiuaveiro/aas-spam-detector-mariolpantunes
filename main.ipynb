# %% [markdown]
# # AAS SPAM Detector
#
# The objective is to develop a SPAM classifier capable of reaching at least 70% accuracy. You can, and should, use all that was presented in the theoretical notebooks.
#
# The dataset is different from the toy one used in the class, instead the work will be done on the Enron SPAM dataset. The Enron-Spam dataset is a fantastic ressource collected by V. Metsis, I. Androutsopoulos and G. Paliouras and described in their publication ["Spam Filtering with Naive Bayes - Which Naive Bayes?"](https://nes.aueb.gr/ipl/nlp/pubs/ceas2006_paper.pdf). The dataset contains a total of 17.171 spam and 16.545 non-spam ("ham") e-mail messages (33.716 e-mails total). The original dataset and documentation can be found [here](http://www2.aueb.gr/users/ion/data/enron-spam/readme.txt).

# %%
import os
import nltk
import math
import tqdm
import joblib
import polars as pl
import numpy as np

from joblib import Parallel, delayed
from collections import Counter

from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef, accuracy_score, f1_score

import gensim
from gensim.models.fasttext import FastText

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /home/mantunes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/mantunes/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mantunes/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/mantunes/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/mantunes/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
df = pl.read_csv('datasets/enron_spam_data.csv.gz')

# %%
df.describe
# Out:
# <bound method DataFrame.describe of shape: (42_619, 2)
# ┌─────────────────────────────────┬─────────┐
# │ text                            ┆ is_spam │
# │ ---                             ┆ ---     │
# │ str                             ┆ i64     │
# ╞═════════════════════════════════╪═════════╡
# │ Re: New Sequences Window        ┆ 0       │
# │                                 ┆         │
# │     …                           ┆         │
# │ [zzzzteana] RE: Alexander       ┆ 0       │
# │                                 ┆         │
# │ Mar…                            ┆         │
# │ [zzzzteana] Moscow bomber       ┆ 0       │
# │                                 ┆         │
# │ Man…                            ┆         │
# │ [IRR] Klez: The Virus That  Wo… ┆ 0       │
# │ Re: [zzzzteana] Nothing like m… ┆ 0       │
# │ …                               ┆ …       │
# │ Какой у тебя любимый цвет? Фан… ┆ 1       │
# │ Что ты сегодня ел, Чудо-печень… ┆ 1       │
# │ Что ты думаешь о спорте? Секре… ┆ 1       │
# │ Какой твой любимый вид спорта,… ┆ 1       │
# │ Ты умеешь петь? Чудо-птица      ┆ 1       │
# └─────────────────────────────────┴─────────┘>

# %%
def _nltk_pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None


def _nltk_pos_lemmatizer(lemmatizer, token, tag):
    if tag is None:
        return lemmatizer.lemmatize(token)
    else:        
        return lemmatizer.lemmatize(token, tag)


def text_pre_processing(txt, m=2):
    if txt is not None:
        lemmatizer = nltk.WordNetLemmatizer()
        stop_words = set(nltk.corpus.stopwords.words('english'))

        tokens = nltk.word_tokenize(txt)
        tokens = [w for w in tokens if w.isalpha()]
        tokens = [w for w in tokens if w not in stop_words]
        tokens = nltk.pos_tag(tokens)
        tokens = [(t[0], _nltk_pos_tagger(t[1])) for t in tokens]
        tokens = [_nltk_pos_lemmatizer(lemmatizer, w, t).lower() for w,t in tokens]
        tokens = [w for w in tokens if len(w) > m]
    else:
        tokens = []
    return tokens

# %%
dataset = [(text, label) for (text, label) in df.rows()]

# %%
corpus = [text for text, _ in dataset]
y = [label for _, label in dataset]

# %%
#tokens_clean = [text_pre_processing(text) for text in corpus]
tokens_clean = Parallel(n_jobs=-1)(delayed(text_pre_processing)(text) for text in corpus)
tokens_merge = [' '.join(line) for line in tokens_clean]

# %%
X_train, X_test, y_train, y_test = train_test_split(tokens_merge, y, test_size=0.2, random_state=42, stratify=y)

# %%
X_train
# Out:
# ['work greatt hello welcome medzonli moonbeam shop please introduce one ieading online pandemonium armaceuticai shop coronal disaster proportionality afflict rhomboid lag chamfer haycock furiosity andmanyother save coachhouse total confi appease dentiaiity worldwide phonetic shlpplng blackleg miilion customer country converter day',
#  'transwestern deal fyi kim original message krishnarao pinnamaneni send wednesday june watson kimberly kiatsupaibul seksan subject transwestern deal let discuss result tomorrow also historical spot price information please see folks thanks krishna',
#  'you hand select free info doctype html public html html head meta meta mshtml body center table tbody font http img http img http img http img http img http font center strong you hand select access exclusive information font http free table tbody center http img http img http noshade font arial you receive mail member subscribe unsubscribe http font arial click here http reply email remove subject line must also include body message unsubscribed any correspondence direct company',
#  'save money get oem software need software visit site might need best regard jenee',
#  'please help clarify guarantee issue already play canadian pipeline power pool office landlord etc impediment closing commencing business operation counterparties unlikely transact new ubsw canadian entity without credit support although parental ubs credit support help structure non creditworthy sub support parental term condition limit old enron structure may well well receive industry peter original message kitchen louise send monday february pat odonnell ubsw com haedicke mark milnthorp rob keohane peter subject please help canada appear issue need make swift progress unlike contract entity counterparties ubs london division ubs warburg energy canada ltd lack parental company guarantee forth come ubs issue two main point current history customer contract lightly subsidiary guarantee secondly credit group ask guarantee customer please let know progress louise',
#  'want send quick mail let know need leave office early today grandmother nursing home well expect live much longer keep debra post back office need assistance absence please see anna mehrer anna available please see debra kathy thank jill',
#  'low rate gtsak homeowner less perfect credit quickly match est provider base need whether home equity loan low rate financing specialize less perfect credit custom help get yes deserve continue visit http www bigezloans net',
#  'guy browsin compulsory',
#  'meter oct beaumont methanol sorry discus bmc lee confirm accuracy bmc buy intend swing buyback brandywine dorcheus control meter therefore responsibility make over unders believe deal place brandywine cover issue november please let know lee understanding nov business please let know thanks ken howard camp lee papayoti hou ect ect thu nguyen hou ect ect kenneth seaman hou ect ect howard camp hou ect ect kristen hanson hou ect ect stella morris hou ect ect julie meyers hou ect ect subject meter oct beaumont methanol lee need answer question resolve issue first show deal volume nov pipeline confirm volume volume agree sell beaumont methanol volume agreement deal ticket say volume confirm hpl dorcheus volume second buyback issue buyback set june per julie meyers note sends every month last note send dec distribution list brandywine nothing issue issue hpl beaumont methanol active buyback place decide use buyback commercial issue need clarification buyback place please notify julie note deal ticket buyback longer effective still active please contact chyral resolve let know final resolution forward howard camp hou ect thu nguyen howard camp hou ect ect subject meter oct beaumont methanol forward thu nguyen hou ect lee papayoti thu nguyen hou ect ect stella morris hou ect ect kristen hanson hou ect ect subject meter oct beaumont methanol data front position call bob dorcheus please call directly issue brandywine beaumont methanol please reference fax chyral hankins beaumont methanol call bob dorcheus also chryal tell problem november inv
#  'duke exchange deal daren several month need demand charge either add adjust katherine give number first time spot deal include exchange deal volume move correct deal demand charge need correct listed change let know would like see spreadsheet deal add demand charge excess charge change demand fee change demand fee deal change demand fee thanks megan',
#  'utf wholly date utf agta pro best utf creation thi utf year feel best fellow modern viagta professional',
#  'six url http six date actually clock long loop today discover run think mile actually and short loop think mile actually bug this upsetting lose mile somewhere anyone find please let know thank run mile last week far week even take account bug fear turn runner father make fun runner grow use say never saw runner smile drive runner point say look another runner smile this weigh heavily psyche formative year measure shame admit become runner becoming runner actually difficult not surprisingly involve run there stuff eventually run important part run mile run mile run around block run around block tomorrow run around block next day find run around two block and next week find run mile then one day run mile stop catch breath get invigorate run another mile and runner that really complicate you run run run and one day discover shoe important old sneaker throw first time try run thing actually good running buy new shoe run run run and later discover stretch important stretch run stretch run stretch run there stuff really matter already runner you learn difference run surface and many mile really put one pair shoe and day run maximize calorie burning and train marathon forth worry just run running key otherwise another fat schmuck lie couch reading',
#  'childers family greeting accept mortgage application bad credit problem get loan small monthly payment approval procedure take less minute visit link fill quick easy form http www dfgsgs info azecwbzmi thank time best regard brooke wolf general manager',
#  'guy ever figure much need alcohol jay try figure much safely spend weed',
#  'post locate fountain youth discover next minute regardless age sex current health status common element change way experience next half life learn increase quality life really something may able reverse problem associate age anthony karpos original message nickole ftqb com mailto merrie mtpl com send friday march augustine raul hrnf com inell estela loriann subject appreciate thank oran sta ruba awake daybreak saw profound delight approach land rise sun find pass big city know boston stopthe machine little depend upon dare make halt',
#  'free entry weekly comp chance win ipod txt pod get entry std txt rate apply detail',
#  'halo item offer great discount tussionex claritin clarinex colchicine melanex plavix meridia avandia penicillin aldactone plavix prilosec diclofenac vioxx biaxin find kinds medicine see http compactify ratesofcancerand com',
#  'talk last several year receive numerous question candid comment many wide range topic espeak session office chairman online mailbox voicemail espeak open informal chat employee management office chairman online mailbox voicemail box design confidential upward feedback tool employee choose anonymity please many openly express thought identity make possible quickly respond question concern kind work environment must strive enron encourage continue send comment thing important many time however want respond contact anonymously good idea observation question way maintain confidentiality future receive anonymous question comment employee question response post emeet allow answer question receive give employee opportunity provide insight choose since emeet open discussion board remember send question comment two way email office chairman office chairman voicemail box confidential call promote open honest communication consistent vision value absolutely vital continue success company hesitant afraid speak mind want hear',
#  'july forward chad cass cec pec sharon beemer chad cass cec pec pec subject july send behalf bruce mcmills hpl eastrans effective july redelivered mobil beaumont fcv hpl tenn sabine thanks',
#  'send cigarattes html body center href http dutyfreediscount com shopaff asp affid img src http www dutyfreediscount com adv jpg border center body html',
#  'and pop ibuprofen help',
#  'meet darren',
#  'hpl noms jan see attach file hplnol hplnol',
#  'course instructor clare regret inform decline invitation due prior commitment day vince kaminski original message clare fitzgerald mailto claref marcusevansch com send monday may vkamins enron com subject course instructor vince writing regard energy derivative train course develop would like invite instructor course preliminary agenda attach brett humphreys risk capital management teach day one wondering would interest cover part day two topic outline modify base feedback training course structure interactive classroom type set limit audience people bring instructor cover material course two day follow please let know think thank clare fitzgerald director training course marcus evans agenda doc',
#  'new this message mime format attempt deliver message html formatting however program support message please settings group change preference text http msn groups html head meta body ffffff basefont arial helvetica sans serif style foreground color color ffffff color hover color color color ffffcc hover color color color color hover color color cccccc primarily tag background color ffffff ffffcc idtoolbar ccccff cccccc img http table middle img middle http font helvetica sans serif new message http one income living img http blockquote http msg font arial helvetica sans serif new table http nowrap mailto oneincomeliving send reply message font verdana arial helvetica sans serif reply img http table nbsp font mailto send reply sender message font verdana arial helvetica sans serif reply sender nbsp nbsp http msg increase number recommendation message img verdana arial helvetica sans serif recommend nowrap font message discussion table font arial helvetica sans serif from http view member information sender font arial helvetica sans serif joyful div img http find use dry milk nbsp save half money buy liquid milk also save space frig recently buy extended warranty internet instead dealer save like nbsp group great suggestion think work home use computer find anything yet anybody update important nbsp make little save little thank http view group wsstrippablebegin http amp amp amp amp img http click here wsstrippableend wsstrippablebegin style admsmlnk verdana system color none admsmlnk hover color underline table tbody font also msn http font start chatting nbsp font nbsp http font listen music font nbsp font nbsp http font house amp home font nbsp font nbsp http font try online dating font nbsp font nbsp http font daily horoscopes font wsstrippableend wsstrippablebegin table img http blockquote font arial helvetica sans serif stop get change often arrive http font settings need help forget password please http font passport member services for question feedback http font contact page want receive future msn group receive message mistake please click remove link message open simply click send your address delete group mail list mailto send request remove group font remove address one income wsstrippableend',
#  'request submit access request liz bellamy enron com please review act upon request receive email requester specify manager please click approval approve request request request create date request liz bellamy enron com resource name exceed resource type application',
#  'really need kiss miss baby from baby',
#  'are cut girl world',
#  'lor anyway thk cant get ticket cos like quite late already wan look frens darren wif',
#  'you sure try make xavier smoke want smoke tell smoke much',
#  'neeed medz save subarctic dlcations pharmsh banquet successfull hippie proven way save mone gallipot usurious doublure furtive quadrat outsat gainsay irreversible damn isva snathe jessamine andmanyother best unhand rlces worldwide utterly lpplng easy tunnel order form total confid drench entiaiity abattoir satisfied customer order seacalf today save',
#  'winfax pro popular software available rock bottom price software windows suite adobe macromedia corel symantec mcafee operate system utility download copy software today microsoft window professional price retail price save microsoft office professional price retail price save adobe photoshop price retail price save macromedia studio price retail price save adobe acrobat professional price retail price save norton internet security pro price retail price save mcafee personal firewall plus price retail price save corel draw graphic suite price retail price save symantec pcanywhere price retail price save adobe illustrator full new version price retail price save ahead nero powerpack price retail price save quicken premier home biz price retail price save winfax pro price retail price save rie mio vie yio mia iil',
#  'start date hourahead hour start date hourahead hour ancillary schedule award variance detect log message parse file portland westdesk california schedule iso final schedule txt',
#  'day agrra adlpex alluum ambleen xaanax tussl nex claal read nearly ninety meet scarcely father development pardon xanaax alium cialiis iaagra ambieen popular medssno long question form pay shiip today theresworldwide shippiing smile prom tion run cialiis iaagra alium xanaax ambieen else parent favorite knew country sake',
#  'cdnow order confirmation dear daren thank shop cdnow email confirm order number check status order make change click copy paste link web browser http cdnow com myorder otid also access order history directly home page order follow item robert earl keen walk distance ship via postal service ship address order daren farmer clarkston spring order total get free cdnow gift certificate buy anything bolt click detail limit one per customer offer good till free motorola startac nokia plan telstreet com great wireless deal area one year agreement require free phone click detail please reply email question order address online order history please visit contact cdnow page use link http cdnow com service order worth fast forward reward program point point pending appear membership summary point earn order ship thanks shop cdnow sincerely customer service cdnow inc music store http cdnow com aol keyword cdnow',
#  'panenergy marketing march production daren deal location centana day gas part exchange agreement need spot deal place different deal ticket exchange deal break spot deal separately thanks fix price etxg gas system march katherine daren farmer ect katherine herrera corp enron enron subject panenergy marketing march production change pricing deal east texas point katherine herrera enron daren farmer hou ect ect sherlyn schumack hou ect ect lisa csikos hou ect ect rita wynne hou ect ect subject panenergy marketing march production daren chance change pricing system duke call several time want get march deal finalize sure tell thanks forward katherine herrera corp enron katherine herrera daren farmer hou ect ect subject panenergy marketing march production deal per conversation yesterday afternoon pls separate centena term deal spot deal sitara march production also need price east texas redelivery change sitara index index per contract price redelivery point thanks katherine',
#  'entra www heartandsoul ganha entradas party zone esta mensagem enviada sob nova legislao sobre correio electrnico seco pargrafo decreto ttulo terceiro aprovado pelo congresso base normativas internacionais sobre spam mail poder ser considerado spam quando inclui uma forma ser removido para remover seu mail devolva nos uma mensagem para unsubscribe heartandsoul com palavra remover linha assunto want remove list please send message word remove subject',
#  'cheap pharmacy want new mexican drug http www druq net',
#  'new easy use web conferencing software html head title new web technology meta meta mshtml body eaeaae sans sarif center table tbody font unlimited web ferencing font subscribe web conference enter per month font connects participant time lus audio charge table tbody leave font manage meeting virtually line application share compatible software need call anytime anywhere anywhere unlimited usage participant large group ilabale lowest rate cent per minunte audio toll include quality easy use service numerous interactive feature table tbody leave font free demo font eliminate reduce travel expense font font try savings turn unnecessary trip problem solve fact find ferences save time wear tear overworked business staff table tbody font find revolutionary concept fill form font required input field font table ffffcc tbody form webc table tbody font arial helvetica name font arial helvetica input font arial helvetica web address input font arial helvetica company name font arial helvetica input font arial helvetica state font arial helvetica input font arial helvetica business phone font arial helvetica input font arial helvetica home phone input font arial helvetica email address font arial helvetica input input submit information table tbody font all information iven herein strictly confidential reason specific use font arial helvetica remove distribution list please mailto remove click font ble',
#  'ice counterparty list louise cut txu ice txu cut also tom moran credit maintains list counterparties trade ice stephanie get list asof today asap thnaks savita',
#  'adv internet marketing communication earn uleio hello read short summary see learn new skill communication direct marketing program internet time earn enable change your life summary just read summary follow action advise start earn serious money you learn new skill communication market internet what deal your total cash investment step first time see message join program take five bill total investment mail follow people purchase five guides communication for guide order buy write sheet plain white paper name address your own email address number name guide buying then fold paper put bill inside sheet paper insert paper bill envelope address envelope name address person whose name show guide mail envelope first class air mail sure put enough postage stamp envelop need send registered mail list five names guide how more effective public speaker order guide cash addition guide receive valuable marketing guide million bucks from internet free charge derrick nguyen whitmore monte usa guide how give business presentation order guide cash tim fai gpo box macau via hong kong guide how write more effectively order guide cash luis pastor apartado bilbao spain guide what social function order guide cash chester waldvogel chestnut way berlin usa guide how sharpen your mind order guide cash siden krondikesvagen ostersund sweden end list five names step these guides email save guides computer hard disk people order guides pay need email guides new buyer step from list name delete name address person show guide replace slot name address person guide slot sure copy name address exactly show check address step delete name address guide replace name address guide slot step delete name address guide replace name address guide slot step delete name address guide replace name address guide slot step delete name address guide replace your own name and address this step name address enter list name receive order guides eventually name list names reach gu
occur upon completion accordance construction contract shall ocurred however bank state past contemplate take operating risk work finance agreement ensure coordinate strategy story bank keep comfortable however risk bank push take period turbine currently evaluting purchase turbine engine require site operational purpose ninth turbine generate set previously discuss plan date lease unit however present offer buy use unit significantly well economics operate condition lease current status budget believe accomplish still original construction budget outline attach table currently expect receive million tax rebate able defer million expenditure contemplate original budget still include unallocated contingency million thanks brett',
#  'supremacy bed sex play must win extreme limit wisdom public call madness thank god duty kiss hardy necessity law everyone hard time appear',
#  'really skateboard despite fact get thrown wind bandage shit arm every five minute',
#  'rebuild fails undeclared usb symbol try rebuild recently post alsa driver package kernel although run red hat use red hat kernel package kernel lovingly download configure built hand call old fashion sadly rpm rebuild fails part way rpm rebuild gcc undeclared function initializer element constant near initialization make error the line question look like usb workaround define define define defined endif endif any suggestion mail list http',
#  'pentax mobile printer scanner mobile printer scanner pentax dsmobile usb portable scanner design hand hand portable compute solution provide feature capability expect desktop scanner advance technology sheet fee scanner feature unique usb power data interface avoids need battery external power adapter barely long weight pocketjet fit easily briefcase computer bag quickly mount vehicle small work area use advanced direct thermal printing technology pentax pocketjet eliminates need messy expensive ink toner ribbon barely long weight pocketjet fit easily briefcase computer bag quickly mount vehicle small work area use advanced direct thermal printing technology pentax pocketjet eliminates need messy expensive ink toner ribbon specification specification specification small compact design measure height depth length weigh ounce ultra portable sheet feed design dsmobile usb allow scan business card size paper size multifunction capability dsmobile usb offer instant transmission print page document via mail fax web copy print material turn document without retyping scan edit image form light weight external power adapter dsmobile usb feature unique usb power data interface draw power directly avoids need external power adapter high quality print direct thermal print technology produce dpi text graphic cost efficient never need replacement cartridge toner add pentax quality paper print flexible buy complete kit customize configuration specific use interface option usb parallel serial available print wireless bluetooth irda warranty one year part labor warranty mobility print page single battery charge recharge battery minute windows pda compatible work print enable handheld laptops desktop run window include window pocketpc palmos high quality print direct thermal print technology produce dpi text graphic cost efficient never need replacement cartridge toner supply pentax quality paper flexible buy complete kit customize configuration specific use interface option attach infrared adapter wireless print usb parallel serial bluetooth interface cable also available warranty one year part labor warranty mobility print page single battery charge recharge battery minute windows pda compatible work print enable handheld laptops desktop run window include window pocketpc palmos rim blackberry visit http www computron com deal one stop distributorjebel ali duty free zonedubai uae www computron com late clearance sale list contact sale department detail please send enquiry dealer emirate net aeor contact via www computron com compaq hewlett packard com dell intel iomega epson aopen creative toshiba apc cisco robotics microsoft canon intellinet targus viewsonic ibm sony lot complaint suggestion contact customerservice computron com tel price dollar work fax jebel ali duty free zone www computron com price availability subject change usa canada without notice receive special offer plain text format reply mail request export email consider spam long include contact information remove instruction message intend dealer resellers somehow gotten list error reason would like removed please reply remove subject line message message send compliance federal legislation commercial mail section paragraph bill title iii pass congress logos trademark property respective owner product may exactly show unsubscribe computron follow link click link copy paste address browser',
#  'anyway shop cos yet dun disturb liao',
#  'remember ask alex pizza',
#  'cut medic cost brand name medic tions cut medic cost brand name medic tions waste time doctor office medication deliver right door hour pay less drug get join million people tire hassle insurance company doctor carry well know drug available unknown well currently special follow item odious name phentermine help eliminate excess body fat fioricet relief headache pain migraine headache tramadol alleviate mild mild severe level pain throughout body ambien cure insomnia sleep disorder prilosec treat acid reflux disease extreme heartburnbe prozac depression ocd eat disorder didrex appetite suppressant help reduce weight prescription free sherryour qualify physician stand serve doggonevisit site today let help help callus atbukwvlkcg begin pgp signature version pgp license commercial use www pgp com pgp signature cut medic cost brand name medic tions',
#  'free sizzling ltc sales materials this message mime format free sizzling ltc sales materials catch ltc advantage ltc prospecting pamplets ltc scriptless flip chart what long term care big myths long term care help client see fact figure need order understand long term care insurance market help learn ltci actually important financial future yours free first appointment your options long term care unique scriptless flip chart includes sales presentation contrast value long term care insurance medicare medicaid family care show ltci alternative make sense statistically prove importance ltci client twilight year yours free first application free pamphlet samples with inquiry forget ask our full portfolio senior products ltc annuity lead programs medicare supplement ltci sales training final expense career opportunities call mailto info ltc advantage today please fill form information name phone city state ltc advantage specializing ltci year http want anybody receive mailing wish receive this professional communication send insurance professional remove mailing list not reply message instead http html head title free sizzling ltc sales materials meta body table center table ffffff right img http free img http sizzling ltc sales materials center img http catch ltc advantage bottom center img http center img http bottom center font arial helvetica ffffff ltc prospecting pamplets center font arial helvetica ffffff ltc scriptless flip chart top cccccc font arial helvetica center what long term care quot big myths long term care help client see fact figure need order understand long term care insurance market help ltci actually important financial nbsp center font yours free first appointment font arial helvetica center your options long term care unique scriptless flip chart font includes sales presentation img contrast value long term care insurance medicare medicaid family show ltci alternative make sense prove importance ltci client twilight center font yours free first application img http center font arial helvetica free pamphlet samples with inquiry img http table table cccccc font ffffff verdana arial helvetica nbsp nbsp nbsp nbsp forget ask font nbsp nbsp nbsp our full portfolio senior products center font verdana arial helvetica ltc annuity font verdana arial helvetica lead programs center font verdana arial helvetica medicare supplement font verdana arial helvetica ltci sales training center font verdana arial helvetica final expense font verdana arial helvetica career opportunities center font arial helvetica img call mailto info ltc advantage today center img http center img http center table form post http table center center font ffffff verdana arial helvetica please fill form information right font arial helvetica name input text contactname right font arial helvetica input text email right font arial helvetica phone input text phone right font arial helvetica city input text city right font arial helvetica state input text state right nbsp input submit btnsubmit submit right nbsp input hide hdnrecipienttxt info input hide hdnsubjecttxt ltc advantage insuranceiq inquiry input center http img http ltc advantage specializing ltci year cccccc center font arial helvetica want receive mailing wish receive this communication send insurance professional remove mailing list not reply message instead http http',
#  'daren wonder would sit one day get general feel end process pat tell leave would help good grasp process whole understand imminent cold weather make thing crazy may best time way let know spend day morning even afternoon whenever good time think help much role thanks mike',
#  'graphic software available cheap oem version good morning offer late oem package graphic publishinq software corel macromedia adobe others adobe photoshop macromedia studio adobe acrobat professionai adobe premiere pro corei designer quickbooks professionai edition adobe paqemaker xara adobe audition discreet studio max adobe goiive adobe effect standard adobe premiere element corel painter adobe lilustrator adobe lndesign adobe creative suite adobe framemaker ulead cool production studio aiias motion buiider professionai quicken premier home biz adobe photoshop eiements adobe premiere pro learn sincerely carson',
#  'your own desk top investigator astounding new software lets you find out almost anything anyone download right charge card need click http http discover everything ever want know friend family enemy employee someone using your identity even boss did you know search anyone anytime anywhere right internet download software right click http http this mammoth collection internet investigative tool research sit provide nearly gigantic search resources locate information people trust screen new tenant roommates housekeeper current past employment people work license plate number name address unlisted phone number long lose friend locate phone number address get copy your fbi file get copy your military file find debtors locate hidden assets check criminal drug driving records lookup someone employment history http http locate old classmate miss family member long lost love background checks employees hire investigate family history birth death government record discover unlisted phone number locate check new old love interest verify credit reports correct wrong information track anyone internet activity see site visit type explore secret web sites conventional search engine never find click http http discover way make untraceable phone calls check adoption record locate missing children relatives dig information friends neighbors boss discover employment opportunities around the world locate transcript court orders state cloak email true address discover find much alimony neighbor pay discover check phone wiretaps check shocked find these thing there limit power software download software less minute click url visit website new charge card need http http long wish hear future offer send message stop subject line click mailto mailto please allow hour take effect please include correspondence message automatic stop robot read all request process automatically',
#  'security center advisory paypal safe department notice paypal fraud mediation request recieved email unusual activity account accordance paypal user agreement ensure account compromised access account limit account access remain limited issue resolve fraud alert code contain message attach fraud mediation request form order verify paypal account registration information fraud alert code please save fraud alert code reference help speed process please access follow form complete verification paypal account registration information please note receive appropriate paypal account verification within hour assume paypal account fraudulent suspend purpose verification ensure paypal account fraudulently use combat fraud community appreciate support understand work together keep paypal safe place send money thank use paypal paypal team please reply mail notification mail send address answer copyright paypal right reserve',
#  'vitro project guess response bob group subset remain intact cover group rimbau may group already mexican group survive give circumstance consider tractebel see ahead sell entire project bet idb would glad rid let talk monday get chance original message kitchen louise send fri miller asset mktg subject vitro project surely cover within virgo team send blackberry wireless handheld',
#  'use handy interest calculator get current interest information kbrte use handy rate calculator get current interest availability data without give private personal information send mediagroup smartmortgageusa question may contact usa offer attn smartmortgageusa box san francisco wish exclude future usa item please use website use choice bottom page kfegdwwverzd',
#  'game uniform team game week let know would assume everyone leave come back run book jersey cost try bring cash wed shirt black red number everyone please try wear black short play like shit least look good bryan',
#  'polyhedron ambiien aagrra ciall xaanax alilum cheeap betide write diphtheria screenplay gliridae fogbank playboy survivance xanaax alium cialiis iaagra ambieen popular medssno long question form phalanger pay shiip todayworldwide shippiing ledge prom tion run cialiis iaagra alium xanaax ambieen',
#  'why wait least wednesday see get',
#  'break wall hold back get university diploma want prosperous future increase earn power money respect call number hour require test class book interview get bachelor master mba doctorate phd diploma receive benefit admiration come diploma one turn call today day week confidentiality assure',
#  'cornhusker daren email kathy benedict mistaken think didnt take end take cornhusker completely october think tenaska still least account therefore gas pathed month believe didnt ticket time recall thanks mark forward mark mccoy corp enron katherine benedict ect daren farmer hou ect ect mark mccoy corp enron enron bob fisher enron enron subject head tenaska partner ltd september guy please bob fisher transport settlement group huge favor please let know txu lonestar transport deal tenaska texas partner enter path manager september hold transport invoice txu lonestar september wait enter actuals system payment thanks kathy',
#  'need jollivie low price med viicodin codeine vla gra vaiium ciaiis nax many moreeee available nowadays http www newholidayplans com tiime maillling removalll requiired fqa gopflxfuse oowhqta vwxsfoyy',
#  'ask santa mini car kid christmas store mini car email browser support follow link com promo php simply cut paste internet browser get see com promo php adz com remove php',
#  'speaking texas friday url http date not supply just reminder speak university texas austin friday give talk hollywood legislative agenda sponsor actlab love see link discuss http http',
#  'argh fuck nobody town',
#  ...]

# %%
# train Bag of Words model
cv = CountVectorizer(ngram_range = (1, 2), max_features=512)
X_train_cv = cv.fit_transform(X_train)
print(f'Training Data CV : {X_train_cv.shape}')

# transform X_test using CV
X_test_cv = cv.transform(X_test)
print(f'Test Data CV : {X_test_cv.shape}')
# Out:
# Training Data CV : (34095, 512)
# Test Data CV : (8524, 512)

# %%
# define the list of classifiers
clfs = [
    ('LR', LogisticRegression(random_state=42, max_iter=600)),
    ('KNN', KNeighborsClassifier(n_neighbors=1)),
    ('NB', GaussianNB()),
    ('RFC', RandomForestClassifier(random_state=42)),
    ('MLP', MLPClassifier(random_state=42, learning_rate='adaptive', max_iter=1000))
]

# whenever possible used joblib to speed-up the training
with joblib.parallel_backend('loky', n_jobs=-1):
    for label, clf in clfs:
        # train the model
        clf.fit(X_train_cv.toarray(), y_train)

        # generate predictions
        predictions = clf.predict(X_test_cv.toarray())

        # compute the performance metrics
        mcc = matthews_corrcoef(y_test, predictions)
        acc = accuracy_score(y_test, predictions)
        f1 = f1_score(y_test, predictions, average='weighted')
        print(f'{label:3} {acc:.2f} {f1:.2f} {mcc:.2f}')
# Out:
# LR  0.91 0.91 0.81
# KNN 0.89 0.89 0.77
# NB  0.70 0.69 0.51
# RFC 0.94 0.94 0.87
# MLP 0.94 0.94 0.87

# %%
#text_model = gensim.models.fasttext.load_facebook_model('vec/cc.en.300.bin.gz')
text_model = gensim.models.fasttext.FastText(vector_size=300, window=7, min_count=3, workers=os.cpu_count(), seed=42)
text_model.build_vocab(tokens_clean)

# %%
text_model

# %%
def div_norm(x):
   norm_value = np.linalg.norm(x)
   if norm_value > 0:
       return x * ( 1.0 / norm_value)
   else:
       return x


def word_vector_to_sentence_vector(sentence:list, model):
    vectors = []
    # for all the tokens in the setence
    for token in sentence:
        if token in model:
            vectors.append(model[token])
    # add the EOS token
    if '\n' in model:
        vectors.append(model['\n'])
    # normalize all the vectors
    vectors = [div_norm(x) for x in vectors]
    return np.mean(vectors, axis=0)

# %%
X = np.array([word_vector_to_sentence_vector(sentence, text_model.wv) for sentence in tqdm.tqdm(tokens_clean)])
# Out:
# 100%|██████████| 42619/42619 [00:36<00:00, 1171.36it/s]

# %%
X
# Out:
# array([[ 0.00279531, -0.00512118, -0.00034927, ..., -0.00136312,
#          0.0035082 ,  0.0112902 ],
#        [ 0.00109208, -0.00869433, -0.00416818, ..., -0.00940189,
#          0.00230878,  0.00696706],
#        [ 0.00596662, -0.01144918,  0.00143926, ..., -0.00331017,
#          0.00716811,  0.01155127],
#        ...,
#        [ 0.00058237,  0.00910582, -0.01642736, ..., -0.03440075,
#          0.02302997, -0.01838688],
#        [-0.00693345,  0.02170273,  0.02433146, ..., -0.0011592 ,
#          0.00071695,  0.01745962],
#        [ 0.00632776, -0.00383493,  0.00124999, ..., -0.0118996 ,
#         -0.03748241,  0.01994425]], dtype=float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
# define the list of classifiers
clfs = [
    ('LR', LogisticRegression(random_state=42, max_iter=600)),
    ('KNN', KNeighborsClassifier(n_neighbors=1)),
    ('NB', GaussianNB()),
    ('RFC', RandomForestClassifier(random_state=42)),
    ('MLP', MLPClassifier(random_state=42, learning_rate='adaptive', max_iter=1000))
]

# whenever possible used joblib to speed-up the training
with joblib.parallel_backend('loky', n_jobs=-1):
    for label, clf in clfs:
        # train the model
        clf.fit(X_train, y_train)

        # generate predictions
        predictions = clf.predict(X_test)

        # compute the performance metrics
        mcc = matthews_corrcoef(y_test, predictions)
        acc = accuracy_score(y_test, predictions)
        f1 = f1_score(y_test, predictions, average='weighted')
        print(f'{label:3} {acc:.2f} {f1:.2f} {mcc:.2f}')
# Out:
# LR  0.85 0.85 0.69
# KNN 0.89 0.89 0.78
# NB  0.57 0.56 0.23
# RFC 0.86 0.86 0.73
# MLP 0.93 0.93 0.86
